# %% [markdown]
# # Let's Grow More VIP

# %% [markdown]
# # Beginner Level Task 04

# %% [markdown]
# # Image to Pencil Sketch with Python

# %% [markdown]
# # Name : Gaus Aqsa Shaheen Gulam

# %% [markdown]
# # Importing Libraries

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt

# %%
import os

# %%
os.getcwd()
# Out:
# "E:\\Collage Notes\\Engineering\\Internship\\Let's Grow More\\data science"

# %%
img=cv2.imread("rose.jpg")
plt.imshow(img)

# %%
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=233x155 at 0x179925431F0>

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_img))
# Out:
# <PIL.Image.Image image mode=L size=233x155 at 0x1799254F040>

# %%
inv_gray_img = 255-gray_img
inv_gray_img
# Out:
# array([[243, 243, 243, ..., 243, 243, 243],
#        [243, 243, 243, ..., 243, 243, 243],
#        [243, 243, 243, ..., 243, 243, 243],
#        ...,
#        [239, 250, 245, ..., 243, 243, 243],
#        [235, 248, 245, ..., 243, 243, 244],
#        [230, 245, 245, ..., 243, 243, 246]], dtype=uint8)

# %%
display(Image.fromarray(inv_gray_img))
# Out:
# <PIL.Image.Image image mode=L size=233x155 at 0x179925D4490>

# %%
blur_img=cv2.GaussianBlur(inv_gray_img, (35,35),0)
display(Image.fromarray(blur_img))
# Out:
# <PIL.Image.Image image mode=L size=233x155 at 0x17991E4D670>

# %%
img=255-blur_img
def dodge(gray_imablur_img):
    return cv2.divide(gray_img, img, scale = 400.0)

# %%
pencil_sketch=dodge(img)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=233x155 at 0x17992575C10>
